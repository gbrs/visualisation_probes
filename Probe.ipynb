# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()
pd.set_option('display.max_columns', None)

# %%
df = sns.load_dataset('taxis')
df.sample(10)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 238   2019-03-09 01:49:19  2019-03-09 01:54:17           1      1.50   6.5
# 5385  2019-03-24 13:57:21  2019-03-24 14:19:29           1      6.16  20.5
# 87    2019-03-28 22:57:05  2019-03-28 23:16:56           1      4.10  16.0
# 3596  2019-03-09 16:42:52  2019-03-09 16:58:29           4      1.58  11.5
# 728   2019-03-15 14:09:58  2019-03-15 14:28:28           4      2.57  13.5
# 4556  2019-03-21 14:33:58  2019-03-21 14:58:38           1      2.20  15.5
# 761   2019-03-22 15:16:17  2019-03-22 15:29:48           1      4.18  15.0
# 1633  2019-03-12 08:05:48  2019-03-12 08:12:25           6      1.07   6.5
# 121   2019-03-13 20:00:10  2019-03-13 20:14:34           1      2.10  11.0
# 905   2019-03-23 00:19:20  2019-03-23 00:26:11           1      1.00   6.5
#
#        tip  tolls  total   color      payment                   pickup_zone  \
# 238   2.55    0.0  12.85  yellow  credit card                          SoHo
# 5385  0.00    0.0  21.30  yellow  credit card             East Harlem North
# 87    0.00    0.0  19.80  yellow         cash                     Hudson Sq
# 3596  0.00    0.0  14.80  yellow         cash  Penn Station/Madison Sq West
# 728   0.00    0.0  16.80  yellow         cash                  Clinton East
# 4556  2.00    0.0  20.80  yellow  credit card                      Union Sq
# 761   3.66    0.0  21.96  yellow  credit card               Lenox Hill East
# 1633  1.46    0.0   8.76  yellow  credit card                  Bloomingdale
# 121   3.05    0.0  18.35  yellow  credit card                  East Chelsea
# 905   1.50    0.0  11.80  yellow  credit card                 Midtown South
#
#                  dropoff_zone pickup_borough dropoff_borough
# 238                  Flatiron      Manhattan       Manhattan
# 5385                 Kips Bay      Manhattan       Manhattan
# 87        Lincoln Square East      Manhattan       Manhattan
# 3596             Clinton East      Manhattan       Manhattan
# 728   Greenwich Village North      Manhattan       Manhattan
# 4556            Midtown North      Manhattan       Manhattan
# 761             Alphabet City      Manhattan       Manhattan
# 1633    Upper West Side North      Manhattan       Manhattan
# 121              East Village      Manhattan       Manhattan
# 905              Midtown East      Manhattan       Manhattan

# %%
df.plot.line('distance', 'total');

# %%
df.plot.scatter(x='distance', y='fare', c=(df.payment=='cash'), cmap="viridis");

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])

df["species"] = pd.Categorical(
    ["setosa"] * 20 + ["versicolor"] * 20 + ["virginica"] * 10
)


df.plot.scatter(x="a", y="b");

# %%
df.plot.scatter(x="a", y="b", c="c", s=50);

# %%
df.distance.plot.hist(bins=100, xlim=(0, 15));

# %%
df.plot.hist(alpha=0.3);

# %%
df.hist();

# %%
df.groupby('payment').total.agg('mean').plot.bar();  ## если не сгруппировать то каждый кэш и кредитка будут отдельными столбиками

# %%
df.groupby('payment').total.agg('mean').plot.barh();

# %%
df.passengers.plot.box();

# %%
df.boxplot(column=['distance', 'total'], by='payment');

# %%
df[['distance', 'total']].plot.box(by='payment');  # почему не срабатывает by!?

# %%
df.groupby('payment').total.agg('sum').plot.pie();  ## если заранее не сгруппировать то каждый кэш и кредитка будут отдельными секторами, похоже

# %%
df.distance.plot.kde();  ## Kernel Density Estimation

# %%
df.total.plot.kde();

# %%
df.plot.hexbin('distance', 'total', xlim=(0,4), ylim=(0, 20));

# %%
df.plot.hexbin('distance', 'total', C='passengers', xlim=(0, 30), ylim=(0, 100));

# %%
df2 = pd.DataFrame({
    'sales': [3, 2, 3, 9, 10, 6],
    'signups': [5, 5, 6, 12, 14, 13],
    'visits': [20, 42, 28, 62, 81, 50],
}, index=pd.date_range(start='2018/01/01', end='2018/07/01',
                       freq='M'))
df2
# Out:
#             sales  signups  visits
# 2018-01-31      3        5      20
# 2018-02-28      2        5      42
# 2018-03-31      3        6      28
# 2018-04-30      9       12      62
# 2018-05-31     10       14      81
# 2018-06-30      6       13      50

# %%
df2.plot.area();

# %%
df3 = pd.DataFrame({
    'sales': [3, 2, 3, 9, 10, 6],
    'signups': [5, 5, 6, 12, 14, 13],
    'visits': [20, 42, 28, 62, 81, 50],
    'dates': pd.date_range(start='2018/01/01', end='2018/07/01', freq='M')})
df3
# Out:
#    sales  signups  visits      dates
# 0      3        5      20 2018-01-31
# 1      2        5      42 2018-02-28
# 2      3        6      28 2018-03-31
# 3      9       12      62 2018-04-30
# 4     10       14      81 2018-05-31
# 5      6       13      50 2018-06-30

# %%
df3.plot.area('dates', ['visits', 'sales', 'signups']);

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize=(9, 12));

# %%
from pandas.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))
bootstrap_plot(data, size=20, samples=50);

# %%
df= sns.load_dataset('taxis')
df.sample(10)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 5140  2019-03-04 19:57:14  2019-03-04 20:02:27           1      1.02   5.5
# 1980  2019-03-06 20:59:57  2019-03-06 21:19:00           1      3.53  15.0
# 3155  2019-03-07 17:56:18  2019-03-07 18:10:01           3      1.79  10.0
# 1135  2019-03-26 22:43:51  2019-03-26 22:50:28           1      1.03   6.5
# 4937  2019-03-02 19:50:23  2019-03-02 20:04:19           2      1.60  10.0
# 752   2019-03-14 18:05:49  2019-03-14 18:10:43           1      0.40   5.0
# 4884  2019-03-06 08:49:58  2019-03-06 08:58:39           3      1.40   8.0
# 1484  2019-03-08 18:22:44  2019-03-08 18:27:26           1      0.88   5.5
# 6390  2019-03-19 09:32:20  2019-03-19 09:36:22           1      0.70   5.0
# 2296  2019-03-20 23:23:46  2019-03-20 23:27:54           1      0.40   4.5
#
#        tip  tolls  total   color      payment                    pickup_zone  \
# 5140  1.96    0.0  11.76  yellow  credit card            Lincoln Square East
# 1980  3.76    0.0  22.56  yellow  credit card      Times Sq/Theatre District
# 3155  0.00    0.0  14.30  yellow         cash            Little Italy/NoLiTa
# 1135  2.06    0.0  12.36  yellow  credit card                           SoHo
# 4937  2.75    0.0  16.55  yellow  credit card           TriBeCa/Civic Center
# 752   0.00    0.0   9.30  yellow         cash        Greenwich Village South
# 4884  0.00    0.0  11.30  yellow         cash          Upper West Side South
# 1484  0.00    0.0   9.80  yellow         cash          Upper West Side South
# 6390  0.00    0.0   5.80   green         cash            Morningside Heights
# 2296  1.65    0.0   9.95  yellow  credit card  Sutton Place/Turtle Bay North
#
#                         dropoff_zone pickup_borough dropoff_borough
# 5140             Lincoln Square East      Manhattan       Manhattan
# 1980  Long Island City/Hunters Point      Manhattan          Queens
# 3155                     Murray Hill      Manhattan       Manhattan
# 1135         Greenwich Village North      Manhattan       Manhattan
# 4937                    East Village      Manhattan       Manhattan
# 752              Little Italy/NoLiTa      Manhattan       Manhattan
# 4884                    Central Park      Manhattan       Manhattan
# 1484           Upper West Side North      Manhattan       Manhattan
# 6390            Central Harlem North      Manhattan       Manhattan
# 2296                  Midtown Center      Manhattan       Manhattan

# %%
df.describe(include='all')
# Out:
#                      pickup              dropoff   passengers     distance  \
# count                  6433                 6433  6433.000000  6433.000000
# unique                 6414                 6425          NaN          NaN
# top     2019-03-07 19:54:40  2019-03-22 11:06:48          NaN          NaN
# freq                      2                    2          NaN          NaN
# mean                    NaN                  NaN     1.539251     3.024617
# std                     NaN                  NaN     1.203768     3.827867
# min                     NaN                  NaN     0.000000     0.000000
# 25%                     NaN                  NaN     1.000000     0.980000
# 50%                     NaN                  NaN     1.000000     1.640000
# 75%                     NaN                  NaN     2.000000     3.210000
# max                     NaN                  NaN     6.000000    36.700000
#
#                fare         tip        tolls        total   color  \
# count   6433.000000  6433.00000  6433.000000  6433.000000    6433
# unique          NaN         NaN          NaN          NaN       2
# top             NaN         NaN          NaN          NaN  yellow
# freq            NaN         NaN          NaN          NaN    5451
# mean      13.091073     1.97922     0.325273    18.517794     NaN
# std       11.551804     2.44856     1.415267    13.815570     NaN
# min        1.000000     0.00000     0.000000     1.300000     NaN
# 25%        6.500000     0.00000     0.000000    10.800000     NaN
# 50%        9.500000     1.70000     0.000000    14.160000     NaN
# 75%       15.000000     2.80000     0.000000    20.300000     NaN
# max      150.000000    33.20000    24.020000   174.820000     NaN
#
#             payment     pickup_zone           dropoff_zone pickup_borough  \
# count          6389            6407                   6388           6407
# unique            2             194                    203              4
# top     credit card  Midtown Center  Upper East Side North      Manhattan
# freq           4577             230                    245           5268
# mean            NaN             NaN                    NaN            NaN
# std             NaN             NaN                    NaN            NaN
# min             NaN             NaN                    NaN            NaN
# 25%             NaN             NaN                    NaN            NaN
# 50%             NaN             NaN                    NaN            NaN
# 75%             NaN             NaN                    NaN            NaN
# max             NaN             NaN                    NaN            NaN
#
#        dropoff_borough
# count             6388
# unique               5
# top          Manhattan
# freq              5206
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
df.T.describe()
# Out:
#              0                      1          2          3          4     \
# count          14                     14         14         14         14
# unique         13                     11         13         13         13
# top     Manhattan  Upper West Side South  Manhattan  Manhattan  Manhattan
# freq            2                      2          2          2          2
#
#              5          6     7          8          9     ...    6423  \
# count          14         14    13         14         14  ...      14
# unique         13         13    10         12         12  ...      12
# top     Manhattan  Manhattan     0  Manhattan  Manhattan  ...  Queens
# freq            2          2     3          2          2  ...       2
#
#              6424      6425       6426  6427       6428  6429      6430  \
# count          14        14         14  14.0         14  14.0        14
# unique         12        12         13  12.0         13  13.0        12
# top     Manhattan  Brooklyn  Manhattan  20.0  Manhattan   0.0  Brooklyn
# freq            2         2          2   2.0          2   2.0         2
#
#             6431      6432
# count         14        14
# unique        12        13
# top     Brooklyn  Brooklyn
# freq           2         2
#
# [4 rows x 6433 columns]

# %%
df.groupby('pickup_borough').agg({'distance': 'median', 'passengers': 'mean'}).plot.bar();

# %%
df = sns.load_dataset('taxis')
df.sample(5)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 4323  2019-03-28 16:12:28  2019-03-28 16:31:44           1      2.40  13.0
# 309   2019-03-08 00:42:58  2019-03-08 00:53:48           2      3.67  12.0
# 6066  2019-03-09 16:11:54  2019-03-09 16:25:18           2      4.45  15.0
# 5622  2019-03-02 22:32:31  2019-03-02 22:41:00           1      1.44   7.5
# 1560  2019-03-28 08:26:59  2019-03-28 08:33:21           1      0.80   6.0
#
#        tip  tolls  total   color      payment           pickup_zone  \
# 4323  4.30    0.0  21.60  yellow  credit card              Flatiron
# 309   3.16    0.0  18.96  yellow  credit card          East Village
# 6066  0.00    0.0  15.80   green         cash              Elmhurst
# 5622  0.00    0.0   8.80   green         cash      Hamilton Heights
# 1560  1.85    0.0  11.15  yellow  credit card  TriBeCa/Civic Center
#
#               dropoff_zone pickup_borough dropoff_borough
# 4323               Seaport      Manhattan       Manhattan
# 309         Yorkville West      Manhattan       Manhattan
# 6066          North Corona         Queens          Queens
# 5622  Central Harlem North      Manhattan       Manhattan
# 1560                  SoHo      Manhattan       Manhattan

# %%
sns.set()

# %%
sns.histplot(df.distance);  # в новых версиях есть
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-cbcdaf7b8206> in <module>
# ----> 1 sns.histplot(df.distance)
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
sns.displot(df.distance);  # в новых версиях есть
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a9597d8e3dd0> in <module>
# ----> 1 sns.displot(df.distance);
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %%
sns.kdeplot(df.distance, shade=True);

# %%
sns.distplot(df.distance);

# %%
sns.jointplot(x="distance", y="fare", data=df.sample(1000), kind='scatter');
# "scatter" | "kde" | "hex" | "reg" | "resid"

# %%
sns.scatterplot(data=df, x='distance', y='fare');

# %%
sns.relplot(data=df, x='distance', y='fare',hue='pickup_borough');

# %%
sns.relplot(data=df.sample(10), x='distance', y='fare', kind='line');

# %%
sns.lmplot(data=df, x='distance', y='fare', hue='pickup_borough');

# %%
sns.catplot("pickup_borough", "fare", "payment", data=df, kind='violin', split=True);
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen".sample(1100)

# %%
sns.boxplot("pickup_borough", "fare", "payment", data=df);

# %%
sns.violinplot(x="pickup_borough", y="fare", hue="payment", data=df, 
                       split=True, inner="quartile");

# %%
sns.distplot(df.distance)
sns.scatterplot(data=df, x='distance', y=df.fare / 300);

# %%
fig, ax = plt.subplots(2, 1)
sns.scatterplot(x='distance', y='fare',hue='pickup_borough', data=df, ax=ax[0])
sns.violinplot(x="pickup_borough", y="fare", hue="payment", data=df, ax=ax[1]);

# %% [markdown]
# Occupation - род занятий?
# Marital_Status - семейное поожение
# Purchase - стоимость?
# Набор данных здесь представляет собой образец транзакций, совершенных в розничном магазине. Магазин хочет лучше знать покупательское поведение в отношении различных продуктов. В частности, здесь проблема представляет собой проблему регрессии, когда мы пытаемся предсказать зависимую переменную (сумму покупки) с помощью информации, содержащейся в других переменных.
# Проблема классификации также может быть решена в этом наборе данных, поскольку некоторые переменные являются категориальными, а некоторые другие подходы могут быть «прогнозированием возраста потребителя» или даже «прогнозированием категории купленных товаров». Этот набор данных также особенно удобен для кластеризации и, возможно, для поиска в нем различных кластеров потребителей.

# %%
sns.set(style='whitegrid')

# %%
df = pd.read_csv('black_friday.csv')
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# 25%              5.000000            9.000000    5866.000000
# 50%              9.000000           14.000000    8062.000000
# 75%             15.000000           16.000000   12073.000000
# max             18.000000           18.000000   23961.000000

# %%
df.describe(include='object')
# Out:
#        Product_ID  Gender     Age City_Category Stay_In_Current_City_Years
# count      537577  537577  537577        537577                     537577
# unique       3623       2       7             3                          5
# top     P00265242       M   26-35             B                          1
# freq         1858  405380  214690        226493                     189192

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 49.2+ MB

# %%
sns.histplot(data=df, x='Gender', hue='Gender', hue_order=['M', 'F']);

# %%
sns.histplot(data=df, x='Age', y='City_Category', hue='Age');

# %%
sns.kdeplot(data=df.sample(1000), x='Purchase', y='Occupation', hue='Gender');

# %%
sns.kdeplot(data=df.sample(1000), x='Purchase', hue='Gender');

# %%
sns.displot(data=df.sample(1000), x='Purchase', hue='Gender', kind='kde', hue_order=['M', 'F']);

# %%
sns.displot(data=df, x='Purchase', y='Occupation', kind="hist");

# %%
df= sns.load_dataset('taxis')
df.sample(5)
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 4002  2019-03-16 08:55:35  2019-03-16 09:37:31           3     10.70  39.0
# 2035  2019-03-03 15:37:03  2019-03-03 15:53:15           1      1.60  11.5
# 3792  2019-03-14 17:42:14  2019-03-14 17:44:51           1      0.57   4.0
# 944   2019-03-03 13:13:56  2019-03-03 13:22:47           1      1.30   8.0
# 4904  2019-03-29 22:21:29  2019-03-29 22:27:37           1      0.50   5.5
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 4002  9.10   5.76  54.66  yellow  credit card       Manhattan Valley
# 2035  2.95   0.00  17.75  yellow  credit card           East Chelsea
# 3792  0.00   0.00   8.30  yellow         cash  Upper West Side North
# 944   1.70   0.00  13.00  yellow  credit card  Upper West Side South
# 4904  0.00   0.00   9.30  yellow         cash           Midtown East
#
#              dropoff_zone pickup_borough dropoff_borough
# 4002    LaGuardia Airport      Manhattan          Queens
# 2035     Garment District      Manhattan       Manhattan
# 3792     Manhattan Valley      Manhattan       Manhattan
# 944   Lincoln Square East      Manhattan       Manhattan
# 4904         Midtown East      Manhattan       Manhattan

# %%
plt.figure(figsize=(10, 6))
for i, feature in enumerate(['passengers', 'pickup_borough', 'color', 'dropoff_borough']):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[feature].astype(str))
    plt.xticks(rotation=0)
    plt.title(feature)

# %%
df= sns.load_dataset('taxis')

# %%
df.sample(5)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 4871 2019-03-20 19:57:49 2019-03-20 20:00:36           1      0.53   4.0
# 3607 2019-03-15 01:36:14 2019-03-15 01:58:53           2     10.85  32.5
# 49   2019-03-04 21:35:00 2019-03-04 21:53:42           1      4.87  17.5
# 1570 2019-03-07 09:24:16 2019-03-07 09:33:31           1      1.20   8.0
# 6206 2019-03-26 08:07:36 2019-03-26 08:15:41           1      1.37   7.5
#
#         tip  tolls  total   color      payment          pickup_zone  \
# 4871   2.34    0.0  10.14  yellow  credit card  Lincoln Square East
# 3607  10.89    0.0  47.19  yellow  credit card         East Village
# 49     0.00    0.0  21.30  yellow         cash         West Village
# 1570   2.25    0.0  13.55  yellow  credit card         West Village
# 6206   1.50    0.0  12.55   green  credit card       Central Harlem
#
#                    dropoff_zone pickup_borough dropoff_borough
# 4871      Upper West Side South      Manhattan       Manhattan
# 3607                     Inwood      Manhattan       Manhattan
# 49        Upper West Side South      Manhattan       Manhattan
# 1570  West Chelsea/Hudson Yards      Manhattan       Manhattan
# 6206      Upper West Side North      Manhattan       Manhattan

# %%
df.at[5330, 'total']
# Out:
# 38.06

# %%
df.loc[5330, 'total']
# Out:
# 38.06

# %%
df.iloc[2, 7]
# Out:
# 14.16

# %%
df.iloc[2][7]
# Out:
# 14.16

# %%
df.total[5330]
# Out:
# 38.06

# %%
plt.figure()  # Создаем рисунок для графика /// обязательно?
# Создаем первую из двух областей графика и задаем текущую ось
plt.subplot(2, 1, 1)  # (rows, columns, panel number)
plt.plot(df[0:10].distance, df[0:10].fare)
plt.subplot(2, 1, 2)  # (rows, columns, panel number)
plt.plot(df[0:10].tip, df[0:10].total);

# %%
df = pd.DataFrame(np.random.randn(10,10))
sns.heatmap(df.corr().round(2), annot=True, cmap='crest');

# %%
df = pd.DataFrame(np.random.randn(10,10))
sns.heatmap(df.corr().round(2), annot=True, cmap='crest');

# %%
df = pd.DataFrame(np.random.randn(10,10))
corr_matrix = df.corr()
((corr_matrix.abs() > 0.8).sum().sum() - 10) // 2
# Out:
# 2

# %%
sns.heatmap(corr_matrix.round(2), annot=True, cmap='crest');

# %%
df = sns.load_dataset('taxis')

# %%
sns.displot(df, x='dropoff_borough', y='pickup_borough');

# %%
plt.figure(figsize=(4, 3))
sns.histplot(df, x='dropoff_borough', y='pickup_borough');

# %%
sns.kdeplot(df, x='distance', y='total');

# %%
plt.barh(df.pickup_borough.value_counts().sort_values(ascending=True).index, df.pickup_borough.value_counts().sort_values(ascending=True).values,)
plt.xticks(rotation=45);

# %%
fig, ax = plt.subplots()
plt.xticks(rotation=45)
# ax.set_xticklabels(ax.get_xticks(), rotation=45)
ax.barh(df.pickup_borough.value_counts().sort_values(ascending=True).index, df.pickup_borough.value_counts().sort_values(ascending=True).values);

# %%
sns.catplot(df.sample(400), y='total', row='color', col='payment', kind='swarm');

# %%
sns.displot(df, x='total', row='color', col='payment');

# %%
sns.relplot(df, x='distance', y='total', row='color', col='payment');

# %%
sns.violinplot(df, x='pickup_borough', y='total', hue='color', split=True, palette=['yellow', 'green']);
# , x='pickup_borough'

# %%
df = sns.load_dataset('taxis')[:5]

# %%
df
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df.total[df.dropoff_zone == 'Yorkville West'] -= 3* df.passengers 
# df.balance[df.city == 'Moscow'] -= 3 * df.sms

# %%
df
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  33.95  yellow  credit card              Hudson Sq
# 4    0.0   4.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
df = sns.load_dataset('taxis')
df.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan
# 3         Yorkville West      Manhattan       Manhattan
# 4         Yorkville West      Manhattan       Manhattan

# %%
s = df.groupby('pickup_borough').sum()['total']

# %%
sd = s.reset_index()

# %%
sns.barplot(sd, x=sd.pickup_borough, y=sd.total);

# %%
sns.barplot(sd, x=s.index, y=s.values);

# %%
s.plot.bar();

# %%
plt.bar(s.index, s.values);

# %%
df.plot.scatter(x='distance', y='fare', alpha=0.1);
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.scatterplot(data=df, x='distance', y='fare', alpha=0.1);

# %%
plt.scatter(x=df.distance, y=df.fare, alpha=0.1);
